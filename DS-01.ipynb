# %%
#Reg No. : 1084
#Name : N.Sindhuja
#Date : 13/10/2022

# %%
#importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#1 Identify Variables and their Types (Quantitative or Qualitative)
from pandas import read_csv
path = r"/content/Enrollments.csv"
data = read_csv(path)
data
# Out:
#      StudentNo  DEGREE  INTERMEDIATE   SSC                      INTERNSHIP
# 0         1001    8.10          76.0  92.0                    Data Science
# 1         1002    8.10          76.0  92.0      MEAN Stack Web Development
# 2         1003    7.80          94.6  92.0      MEAN Stack Web Development
# 3         1004    9.03          89.5  89.0                    Data Science
# 4         1005    8.38          87.0  90.0      MEAN Stack Web Development
# ..         ...     ...           ...   ...                             ...
# 292       2188    8.70          94.1  93.0                    Data Science
# 293       2189    8.45          90.0  93.0                    Data Science
# 294       2190    8.40          94.9  98.0                    Data Science
# 295       2191    7.06          90.6  88.0  Cloud Computing Services (AWS)
# 296       2192    7.50          95.5  95.0  Cloud Computing Services (AWS)
#
# [297 rows x 5 columns]

# %%
data.dtypes
# Out:
# StudentNo         int64
# DEGREE          float64
# INTERMEDIATE    float64
# SSC             float64
# INTERNSHIP       object
# dtype: object

# %%
#2 Size of Data (No. of Columns and Rows)
data.shape
# Out:
# (297, 5)

# %%
#3 Prepare Histogram for Degree, Inter and 10th Class
data.hist('DEGREE',bins=25)
plt.xlabel('DEGREE')
plt.ylabel('count')
plt.show()

# %%
data.hist('INTERMEDIATE',bins=25)
plt.xlabel('INTERMEDIATE')
plt.ylabel('count')
plt.show()

# %%
data.hist('SSC',bins=25)
plt.xlabel('SSC')
plt.ylabel('count')
plt.show()

# %%
#4 Create Pie-Chart to represent the Enrollments for each Internship Program
plt.pie(data['INTERNSHIP'].value_counts(),labels=['Data Science', 'MEAN Stack Web Development','Cloud Computing Services (AWS)'],autopct="%0.2f")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa80a3dcb90>,
# ...
#  [Text(-0.08717493802411254, 1.0965402547013459, 'Data Science'),
#   Text(-0.48847327200215157, -0.9855931526443922, 'MEAN Stack Web Development'),
#   Text(0.9437817631085101, -0.5650451164498216, 'Cloud Computing Services (AWS)')],
#  [Text(-0.047549966194970476, 0.598112866200734, '52.53'),
#   Text(-0.2664399665466281, -0.5375962650787593, '30.30'),
#   Text(0.5147900526046418, -0.30820642715444807, '17.17')])

# %%
#5 Find No. of Enrollments for each Internship Program
from collections import Counter
Enrollments=Counter(data['INTERNSHIP'])
Enrollments
# Out:
# Counter({'Data Science': 156,
#          'MEAN Stack Web Development': 51,
#          'Cloud Computing Services (AWS)': 90})

# %%
#6 Find Measure of Central Tendency: MEAN, MEDIAN, MODE for Degree, Inter and
print("Mean of degree =",data['DEGREE'].mean())
print("Median degree =",data['DEGREE'].median())
print("Mode degree =",data['DEGREE'].mode())
# Out:
# Mean of degree = 7.928080808080809
# Median degree = 8.0
# Mode degree = 0    7.0
# dtype: float64

# %%
print("Mean inter =",data['INTERMEDIATE'].mean())
print("Median inter =",data['INTERMEDIATE'].median())
print("Mode inter =",data['INTERMEDIATE'].mode())
# Out:
# Mean inter = 88.66262626262626
# Median inter = 90.8
# Mode inter = 0    95.0
# dtype: float64

# %%
print("Mean 10th =",data['SSC'].mean())
print("Median 10th =",data['SSC'].median())
print("Mode 10th =",data['SSC'].mode())
# Out:
# Mean 10th = 88.10673400673402
# Median 10th = 90.0
# Mode 10th = 0    95.0
# dtype: float64

# %%
#7 Find Measure of Variance: Minimum, Maximum, Range, Mean Deviation, Standard Deviation,Co-efficient of Variation for Degree,Inter and 10th
print("Minimum =",data['DEGREE'].min())
print("Maximum =",data['DEGREE'].max())
print("Range =",9.53-5.8)
print("Mean Deviation =",data['DEGREE'].mad())
print("Standard Deviation =",data['DEGREE'].std())
cv = lambda x: np.std(x, ddof=1) / np.mean(x) * 100
print("Co-efficient of Variation =",cv(data['DEGREE']))
# Out:
# Minimum = 5.8
# Maximum = 9.53
# Range = 3.7299999999999995
# Mean Deviation = 0.6475638540285004
# Standard Deviation = 0.7855786429497713
# Co-efficient of Variation = 9.90881225818308

# %%
print("Minimum =",data['INTERMEDIATE'].min())
print("Maximum =" ,data['INTERMEDIATE'].max())
print("Range =",99.4-65)
print("Mean Deviation =",data['INTERMEDIATE'].mad())
print("Standard Deviation =",data['INTERMEDIATE'].std())
cv = lambda x: np.std(x, ddof=1) / np.mean(x) * 100
print("Co-efficient of Variation =",cv(data['INTERMEDIATE']))
# Out:
# Minimum = 65.0
# Maximum = 99.4
# Range = 34.400000000000006
# Mean Deviation = 6.0779825187906
# Standard Deviation = 7.35573276879534
# Co-efficient of Variation = 8.29631726338337

# %%
print("Minimum =",data['SSC'].min())
print("Maximum =",data['SSC'].max())
print("Range =",99-38.4)
print("Mean Deviation =",data['SSC'].mad())
print("Standard Deviation =",data['SSC'].std())
cv = lambda x: np.std(x, ddof=1) / np.mean(x) * 100
print("Co-efficient of Variation =",cv(data['SSC']))
# Out:
# Minimum = 38.4
# Maximum = 99.0
# Range = 60.6
# Mean Deviation = 6.5146492988243825
# Standard Deviation = 9.027984183574615
# Co-efficient of Variation = 10.24664491920062

# %%
#8 Measures of Position: Standard Scores, Inter-quartile Range for Degree, Inter and 10th
import numpy as np
import scipy.stats as stats
print(stats.zscore(data['DEGREE']))
print("-----------------------------------------")
q3 = np.percentile(data['DEGREE'],75)
q1 = np.percentile(data['DEGREE'],25)
iqr = q3 - q1
print('The Interquartile Range for DEGREE =',iqr)
# Out:
# 0      0.219213
# 1      0.219213
# 2     -0.163315
# 3      1.405052
# 4      0.576240
#          ...
# 292    0.984271
# 293    0.665497
# 294    0.601742
# 295   -1.106886
# 296   -0.545844
# Name: DEGREE, Length: 297, dtype: float64
# -----------------------------------------
# The Interquartile Range for DEGREE = 1.1600000000000001

# %%
import numpy as np
import scipy.stats as stats
print(stats.zscore(data['INTERMEDIATE']))
print("-----------------------------------------")
q3 = np.percentile(data['INTERMEDIATE'],75)
q1 = np.percentile(data['INTERMEDIATE'],25)
iqr = q3 - q1
print('The Interquartile Range for INTERMEDIATE =',iqr)
# Out:
# 0     -1.724369
# 1     -1.724369
# 2      0.808539
# 3      0.114032
# 4     -0.226413
#          ...
# 292    0.740450
# 293    0.182121
# 294    0.849392
# 295    0.263827
# 296    0.931099
# Name: INTERMEDIATE, Length: 297, dtype: float64
# -----------------------------------------
# The Interquartile Range for INTERMEDIATE = 11.599999999999994

# %%
import numpy as np
import scipy.stats as stats
print(stats.zscore(data['SSC']))
print("-----------------------------------------")
q3 = np.percentile(data['SSC'],75)
q1 = np.percentile(data['SSC'],25)
iqr = q3 - q1
print('The Interquartile Range for SSC =',iqr)
# Out:
# 0      0.431972
# 1      0.431972
# 2      0.431972
# 3      0.099111
# 4      0.210065
#          ...
# 292    0.542926
# 293    0.542926
# 294    1.097694
# 295   -0.011843
# 296    0.764833
# Name: SSC, Length: 297, dtype: float64
# -----------------------------------------
# The Interquartile Range for SSC = 10.0

# %%
#9 Create Box Plot and Identify Outliers for Degree, Inter and 10th 
data['DEGREE'].plot(kind='box')
plt.show()
data['INTERMEDIATE'].plot(kind='box')
plt.show()
data['SSC'].plot(kind='box')
plt.show()
def outlier(a):
 q1 = np.quantile(a,0.25)
 q2 = np.quantile(a,0.75)
 m = np.median(a)
 iqr = q2-q1
 u_bound = q2+(1.5*iqr)
 l_bound = q1-(1.5*iqr)
 # print(iqr,u_bound,l_bound)
 # print("Inter Quartile Range:",iqr)
 outliers = a[(a<= l_bound)|(a>= u_bound)]
 print("outliers in boxplot:\n{}".format(outliers))
outlier(data['DEGREE'])
outlier(data['INTERMEDIATE'])
outlier(data['SSC'])
# Out:
# outliers in boxplot:
# Series([], Name: DEGREE, dtype: float64)
# outliers in boxplot:
# 271    65.0
# Name: INTERMEDIATE, dtype: float64
# outliers in boxplot:
# 5      64.0
# 7      70.0
# 31     60.0
# 51     68.0
# 69     60.0
# 82     65.6
# 86     50.0
# 107    64.0
# 236    38.4
# 237    67.0
# 243    40.2
# 270    65.0
# 288    65.0
# Name: SSC, dtype: float64

# %%
#10 Identify No. of Students with 90% percentile for Degree, Inter and 10th Class
from collections import Counter
p1=Counter(data['DEGREE']>=9)
print("No. of Students with 90% in DEGREE =",p1)
p2=Counter(data['INTERMEDIATE']>=90)
print("No. of Students with 90% in INTERMEDIATE =",p2)
p3=Counter(data['SSC']>=90)
print("No. of Students with 90% in SSC =",p3)
# Out:
# No. of Students with 90% in DEGREE = Counter({False: 273, True: 24})
# No. of Students with 90% in INTERMEDIATE = Counter({True: 164, False: 133})
# No. of Students with 90% in SSC = Counter({True: 164, False: 133})
